# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
col_names=["sepallength","sepalwidth","petallength","petalwidth","class"]
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
dataset=pd.read_csv(url,names=col_names)

# %%
dataset
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset=dataset.values[:,0:4]
lables=dataset.values[:,-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2834315070.py in <cell line: 0>()
# ----> 1 dataset=dataset.values[:,0:4]
#       2 lables=dataset.values[:,-1]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
dataset
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
import math
def distance(x1,x2):
  distances=0.0
  for i in range(len(x1)):
    distances+=(x1[i]-x2[i])**2
  return(math.sqrt(distances))

# %%
testing_data = dataset[69, 0:4]

# %%
distance_cumm = []
for i in range(len(dataset)):
    distance_cumm.append(distance(dataset[i], testing_data))

# %%
distance_cumm
# Out:
# [2.882707061079915,
#  2.792848008753788,
#  2.9782545223670858,
#  2.816025568065745,
#  2.9376861643136762,
#  2.7073972741361767,
#  2.9495762407505253,
#  2.7820855486487113,
#  2.942787793912432,
#  2.758622844826744,
#  2.8372521918222215,
#  2.747726332806817,
#  2.8530685235374214,
#  3.2832910318764004,
#  3.22335229225724,
#  3.1416556144810017,
#  3.0413812651491097,
#  2.8530685235374214,
#  2.6795522013948525,
#  2.8879058156387303,
#  2.5495097567963927,
#  2.817800560721074,
#  3.3808283008753937,
#  2.4677925358506134,
#  2.5019992006393608,
#  2.5903667693977237,
#  2.6362852652928135,
#  2.7802877548915688,
#  2.8337254630609507,
#  2.7202941017470885,
#  2.6645825188948455,
#  2.6645825188948455,
#  3.0789608636681303,
#  3.1559467676119,
#  2.758622844826744,
#  2.9916550603303182,
#  2.9291637031753615,
#  2.758622844826744,
#  3.043024810940587,
#  2.7622454633866265,
#  2.959729717389748,
#  2.9410882339705484,
#  3.0822070014844876,
#  2.626785107312739,
# ...

# %%
distance_cumm.sort()

# %%
distance_cumm
# Out:
# [0.0,
#  0.17320508075688762,
#  0.24494897427831766,
#  0.2645751311064588,
#  0.2645751311064592,
#  0.30000000000000016,
#  0.31622776601683794,
#  0.360555127546399,
#  0.4123105625617663,
#  0.4242640687119284,
#  0.43588989435406744,
#  0.5196152422706634,
#  0.5291502622129185,
#  0.5385164807134499,
#  0.5385164807134503,
#  0.5477225575051663,
#  0.5744562646538027,
#  0.6000000000000002,
#  0.6244997998398397,
#  0.7071067811865476,
#  0.7681145747868612,
#  0.8485281374238572,
#  0.8774964387392121,
#  0.8774964387392122,
#  0.8831760866327845,
#  0.8999999999999998,
#  0.9055385138137421,
#  0.9165151389911681,
#  0.932737905308881,
#  0.9848857801796108,
#  0.9949874371066202,
#  1.0000000000000004,
#  1.0295630140987,
#  1.039230484541326,
#  1.0677078252031311,
#  1.0999999999999994,
#  1.2449899597988732,
#  1.2569805089976536,
#  1.2609520212918492,
#  1.2727922061357857,
#  1.2845232578665133,
#  1.2845232578665136,
#  1.2999999999999998,
#  1.307669683062202,
# ...

# %%
k = 7
distance_cumm = []

# Compute distance and store with label
for i in range(len(dataset)):
    d = distance(dataset[i], testing_data)   # your distance function
    distance_cumm.append((d, labels[i]))     # tuple: (distance, label)

# Sort by distance (ascending)
distance_cumm.sort(key=lambda x: x[0])

# Select top-k labels
label_topk = []
for i in range(k):
    label_topk.append(distance_cumm[i][1])

print("Top-k labels:", label_topk)
# Out:
# Top-k labels: ['Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor']

# %%
label_topk
# Out:
# ['Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor']

# %%
from collections import Counter
count=Counter(label_topk)

# %%
count
# Out:
# Counter({'Iris-versicolor': 7})

# %%
print("Our final predicted label is",count.most_common(1)[0][0])
# Out:
# Our final predicted label is Iris-versicolor
