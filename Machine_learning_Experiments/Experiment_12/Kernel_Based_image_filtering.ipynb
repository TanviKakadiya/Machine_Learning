# %%
path = r'/content/jpegxl-home_optimized_10.jpg'
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
import numpy as np
from scipy.ndimage import convolve

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread(path,cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=184x184>

# %%
#kernel declaration
identity=np.array([[0,0,0],[0,1,0],[0,0,0]])
blur=np.ones((7,7),dtype=float)*(1/49)
horizontal=np.array([[1,2,1],[0,0,0],[-1,-2,-1]])

# %%
#kernel declaration
identity=np.array([[0,0,0],[0,1,0],[0,0,1]])
blur=np.ones((7,7), dtype=float)*(1/40)
horizontal = np.array([[1,1,1],[0,0,0,],[-1,-1,-1]])
identity
# Out:
# array([[0, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
kernel=horizontal
img2=convolve(img,kernel)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=184x184>

# %%
blur
# Out:
# array([[0.02040816, 0.02040816, 0.02040816, 0.02040816, 0.02040816,
#         0.02040816, 0.02040816],
#        [0.02040816, 0.02040816, 0.02040816, 0.02040816, 0.02040816,
#         0.02040816, 0.02040816],
#        [0.02040816, 0.02040816, 0.02040816, 0.02040816, 0.02040816,
#         0.02040816, 0.02040816],
#        [0.02040816, 0.02040816, 0.02040816, 0.02040816, 0.02040816,
#         0.02040816, 0.02040816],
#        [0.02040816, 0.02040816, 0.02040816, 0.02040816, 0.02040816,
#         0.02040816, 0.02040816],
#        [0.02040816, 0.02040816, 0.02040816, 0.02040816, 0.02040816,
#         0.02040816, 0.02040816],
#        [0.02040816, 0.02040816, 0.02040816, 0.02040816, 0.02040816,
#         0.02040816, 0.02040816]])

# %%
identity
# Out:
# array([[0, 0, 0],
#        [0, 1, 0],
#        [0, 0, 0]])

# %%
kernel=identity
img2=convolve(img,kernel)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=184x184>
